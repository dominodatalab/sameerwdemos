# %%
import os
import sys
sys.path.append("/mnt/code/")

# %%
import torchmetrics as tm

# %%
import os
import tempfile
import time

import mlflow
from ray import air, tune
from ray.air import session
from domino_mlflow_utils.mlflow_callback import *
# Out:
# 2024-03-04 10:00:22,861	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.7.5 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2024-03-04 10:00:23,161	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.7.5 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
def evaluation_fn(step, width, height):
    return (0.1 + width * step / 100) ** (-1) + height * 0.1


def train_function(config):
    width, height = config["width"], config["height"]

    for step in range(config.get("steps", 100)):
        # Iterative training function - can be any arbitrary training procedure
        intermediate_score = evaluation_fn(step, width, height)
        # Feed the score back to Tune.
        session.report({"iterations": step, "mean_loss": intermediate_score})
        time.sleep(0.1)

# %%
def tune_with_callback(mlflow_tracking_uri, experiment_name,finish_fast=False):
    cb = MyMLflowLoggerCallback(
                    tracking_uri=mlflow_tracking_uri,
                    experiment_name=experiment_name,
                    save_artifact=True,
                )
    tuner = tune.Tuner(
        train_function,
        tune_config=tune.TuneConfig(num_samples=5),        
        run_config=air.RunConfig(
            name="mlflow",
            callbacks=[
                cb
            ],
        ),
        param_space={
            "width": tune.randint(10, 100),
            "height": tune.randint(0, 100),
            "steps": 5 if finish_fast else 100,
        },
    )
    results = tuner.fit()
    cb.log_end_parent_run()

# %%
import mlflow
import os
import ray
import logging
from domino_mlflow_utils.mlflow_callback import *

temp_dir='/tmp'

if not ray.is_initialized():
    service_host = os.environ["RAY_HEAD_SERVICE_HOST"]
    service_port = os.environ["RAY_HEAD_SERVICE_PORT"]
    address=f"ray://{service_host}:{service_port}"
    #temp_dir='/mnt/data//{}/'.format(os.environ['DOMINO_PROJECT_NAME']) #set to a dataset
    ray.init(address=address, _temp_dir=temp_dir,runtime_env={"py_modules": ['/mnt/code/domino_mlflow_utils']})

print('Ray Initializied')
print(f'Ray Host={service_host} and Ray Port={service_port}')

experiment_name = 'RAYv7'+'-' + os.environ['DOMINO_STARTING_USERNAME'] + '-' + os.environ['DOMINO_PROJECT_NAME']
tune_with_callback(os.environ['CLUSTER_MLFLOW_TRACKING_URI'], experiment_name,finish_fast=True)

#tune_with_setup(os.environ['CLUSTER_MLFLOW_TRACKING_URI'], experiment_name,finish_fast=True)
df = mlflow.search_runs(
        [mlflow.get_experiment_by_name(experiment_name).experiment_id]
    )
print(df)
# Out:
# (TunerInternal pid=1010) [output] This will use the new output engine with verbosity 1. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# (TunerInternal pid=1010) AIR_VERBOSITY is set, ignoring passed-in ProgressReporter for now.
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Configuration for experiment     mlflow                │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ Search algorithm                 BasicVariantGenerator │
# (TunerInternal pid=1010) │ Scheduler                        FIFOScheduler         │
# (TunerInternal pid=1010) │ Number of trials                 5                     │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) View detailed results here: /home/ray/ray_results/mlflow
# (TunerInternal pid=1010) To visualize your results with TensorBoard, run: `tensorboard --logdir /home/ray/ray_results/mlflow`
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial status: 5 PENDING
# (TunerInternal pid=1010) Current time: 2024-03-04 02:00:39. Total running time: 0s
# (TunerInternal pid=1010) Logical resource usage: 0/4 CPUs, 0/0 GPUs
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial name                   status       width     height │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ train_function_0be04_00000   PENDING         42         11 │
# (TunerInternal pid=1010) │ train_function_0be04_00001   PENDING         79         56 │
# (TunerInternal pid=1010) │ train_function_0be04_00002   PENDING         52          8 │
# (TunerInternal pid=1010) │ train_function_0be04_00003   PENDING         89         59 │
# (TunerInternal pid=1010) │ train_function_0be04_00004   PENDING         21         14 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00001 started with configuration:
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00001 config        │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ height                                      56 │
# (TunerInternal pid=1010) │ steps                                        5 │
# (TunerInternal pid=1010) │ width                                       79 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00000 started with configuration:
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00000 config        │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ height                                      11 │
# (TunerInternal pid=1010) │ steps                                        5 │
# (TunerInternal pid=1010) │ width                                       42 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00003 started with configuration:
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00003 config        │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ height                                      59 │
# (TunerInternal pid=1010) │ steps                                        5 │
# (TunerInternal pid=1010) │ width                                       89 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00002 started with configuration:
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00002 config        │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ height                                       8 │
# (TunerInternal pid=1010) │ steps                                        5 │
# (TunerInternal pid=1010) │ width                                       52 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00000 completed after 5 iterations at 2024-03-04 02:00:55. Total running time: 15s
# (TunerInternal pid=1010) ╭─────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00000 result             │
# (TunerInternal pid=1010) ├─────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ checkpoint_dir_name                                 │
# (TunerInternal pid=1010) │ time_this_iter_s                            0.10061 │
# (TunerInternal pid=1010) │ time_total_s                                0.40313 │
# (TunerInternal pid=1010) │ training_iteration                                5 │
# (TunerInternal pid=1010) │ iterations                                        4 │
# (TunerInternal pid=1010) │ mean_loss                                    1.6618 │
# (TunerInternal pid=1010) ╰─────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00004 started with configuration:
# (TunerInternal pid=1010) ╭────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00004 config        │
# (TunerInternal pid=1010) ├────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ height                                      14 │
# (TunerInternal pid=1010) │ steps                                        5 │
# (TunerInternal pid=1010) │ width                                       21 │
# (TunerInternal pid=1010) ╰────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00003 completed after 5 iterations at 2024-03-04 02:00:57. Total running time: 17s
# (TunerInternal pid=1010) ╭─────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00003 result             │
# (TunerInternal pid=1010) ├─────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ checkpoint_dir_name                                 │
# (TunerInternal pid=1010) │ time_this_iter_s                            0.10029 │
# (TunerInternal pid=1010) │ time_total_s                                0.40275 │
# (TunerInternal pid=1010) │ training_iteration                                5 │
# (TunerInternal pid=1010) │ iterations                                        4 │
# (TunerInternal pid=1010) │ mean_loss                                   6.17322 │
# (TunerInternal pid=1010) ╰─────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00002 completed after 5 iterations at 2024-03-04 02:01:08. Total running time: 28s
# (TunerInternal pid=1010) ╭─────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00002 result             │
# (TunerInternal pid=1010) ├─────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ checkpoint_dir_name                                 │
# (TunerInternal pid=1010) │ time_this_iter_s                            0.10074 │
# (TunerInternal pid=1010) │ time_total_s                                0.40298 │
# (TunerInternal pid=1010) │ training_iteration                                5 │
# (TunerInternal pid=1010) │ iterations                                        4 │
# (TunerInternal pid=1010) │ mean_loss                                   1.25872 │
# (TunerInternal pid=1010) ╰─────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00001 completed after 5 iterations at 2024-03-04 02:01:09. Total running time: 29s
# (TunerInternal pid=1010) ╭─────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00001 result             │
# (TunerInternal pid=1010) ├─────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ checkpoint_dir_name                                 │
# (TunerInternal pid=1010) │ time_this_iter_s                            0.10076 │
# (TunerInternal pid=1010) │ time_total_s                                0.40342 │
# (TunerInternal pid=1010) │ training_iteration                                5 │
# (TunerInternal pid=1010) │ iterations                                        4 │
# (TunerInternal pid=1010) │ mean_loss                                   5.90675 │
# (TunerInternal pid=1010) ╰─────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial status: 4 TERMINATED | 1 RUNNING
# (TunerInternal pid=1010) Current time: 2024-03-04 02:01:10. Total running time: 30s
# (TunerInternal pid=1010) Logical resource usage: 3.0/4 CPUs, 0/0 GPUs
# (TunerInternal pid=1010) ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial name                   status         width     height      loss     iter     total time (s)     iterations │
# (TunerInternal pid=1010) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ train_function_0be04_00004   RUNNING           21         14   2.76986        4           0.302476              3 │
# (TunerInternal pid=1010) │ train_function_0be04_00000   TERMINATED        42         11   1.6618         5           0.403134              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00001   TERMINATED        79         56   5.90675        5           0.403418              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00002   TERMINATED        52          8   1.25872        5           0.402976              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00003   TERMINATED        89         59   6.17322        5           0.402754              4 │
# (TunerInternal pid=1010) ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial train_function_0be04_00004 completed after 5 iterations at 2024-03-04 02:01:12. Total running time: 32s
# (TunerInternal pid=1010) ╭─────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial train_function_0be04_00004 result             │
# (TunerInternal pid=1010) ├─────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ checkpoint_dir_name                                 │
# (TunerInternal pid=1010) │ time_this_iter_s                            0.10043 │
# (TunerInternal pid=1010) │ time_total_s                                 0.4029 │
# (TunerInternal pid=1010) │ training_iteration                                5 │
# (TunerInternal pid=1010) │ iterations                                        4 │
# (TunerInternal pid=1010) │ mean_loss                                   2.46383 │
# (TunerInternal pid=1010) ╰─────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
# (TunerInternal pid=1010) Trial status: 5 TERMINATED
# (TunerInternal pid=1010) Current time: 2024-03-04 02:01:12. Total running time: 32s
# (TunerInternal pid=1010) Logical resource usage: 1.0/4 CPUs, 0/0 GPUs
# (TunerInternal pid=1010) ╭───────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# (TunerInternal pid=1010) │ Trial name                   status         width     height      loss     iter     total time (s)     iterations │
# (TunerInternal pid=1010) ├───────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# (TunerInternal pid=1010) │ train_function_0be04_00000   TERMINATED        42         11   1.6618         5           0.403134              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00001   TERMINATED        79         56   5.90675        5           0.403418              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00002   TERMINATED        52          8   1.25872        5           0.402976              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00003   TERMINATED        89         59   6.17322        5           0.402754              4 │
# (TunerInternal pid=1010) │ train_function_0be04_00004   TERMINATED        21         14   2.46383        5           0.402901              4 │
# (TunerInternal pid=1010) ╰───────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# (TunerInternal pid=1010)
#                              run_id experiment_id    status  \
# 0  a3a64109331a4e30b22e296f0f5b926d             9  FINISHED
# 1  41f59ef96388400184e5ce2076d521d6             9  FINISHED
# 2  a61f559e9c3d45cab7f46e1b0fdc87cd             9  FINISHED
# 3  7b666a4d707a4a259230a659c9b9c904             9  FINISHED
# 4  35dabad9c7f1496f97193293c1db0d88             9  FINISHED
# 5  adeeaf4e089a4730bc51add50a56fcb2             9   RUNNING
#
#                                         artifact_uri  \
# 0  mlflow-artifacts:/mlflow/a3a64109331a4e30b22e2...
# 1  mlflow-artifacts:/mlflow/41f59ef96388400184e5c...
# 2  mlflow-artifacts:/mlflow/a61f559e9c3d45cab7f46...
# 3  mlflow-artifacts:/mlflow/7b666a4d707a4a259230a...
# 4  mlflow-artifacts:/mlflow/35dabad9c7f1496f97193...
# 5  mlflow-artifacts:/mlflow/adeeaf4e089a4730bc51a...
#
#                         start_time                         end_time  \
# 0 2024-03-04 10:00:56.111000+00:00 2024-03-04 10:01:12.152000+00:00
# 1 2024-03-04 10:00:44.690000+00:00 2024-03-04 10:01:08.342000+00:00
# 2 2024-03-04 10:00:43.380000+00:00 2024-03-04 10:00:57.173000+00:00
# 3 2024-03-04 10:00:42.996000+00:00 2024-03-04 10:00:55.081000+00:00
# 4 2024-03-04 10:00:42.629000+00:00 2024-03-04 10:01:09.190000+00:00
# 5 2024-03-04 10:00:39.489000+00:00                              NaT
#
#    metrics.iterations  metrics.config/height  metrics.done  \
# 0                 4.0                   14.0           0.0
# 1                 4.0                    8.0           0.0
# 2                 4.0                   59.0           0.0
# 3                 4.0                   11.0           0.0
# 4                 4.0                   56.0           0.0
# 5                 NaN                    NaN           NaN
#
#    metrics.config/width  ...  tags.mlflow.domino.user_id  \
# 0                  21.0  ...    65df309894ef6c5ddd8b2705
# 1                  52.0  ...    65df309894ef6c5ddd8b2705
# 2                  89.0  ...    65df309894ef6c5ddd8b2705
# 3                  42.0  ...    65df309894ef6c5ddd8b2705
# 4                  79.0  ...    65df309894ef6c5ddd8b2705
# 5                   NaN  ...    65df309894ef6c5ddd8b2705
#
#    tags.mlflow.domino.user  tags.mlflow.source.type  tags.mlflow.user  \
# 0         integration-test                 NOTEBOOK  integration-test
# 1         integration-test                 NOTEBOOK  integration-test
# 2         integration-test                 NOTEBOOK  integration-test
# 3         integration-test                 NOTEBOOK  integration-test
# 4         integration-test                 NOTEBOOK  integration-test
# 5         integration-test                 NOTEBOOK  integration-test
#
#      tags.mlflow.domino.root_run_id  tags.mlflow.domino.run_id  \
# 0  adeeaf4e089a4730bc51add50a56fcb2   65e5954f46b29e1208590121
# 1  adeeaf4e089a4730bc51add50a56fcb2   65e5954f46b29e1208590121
# 2  adeeaf4e089a4730bc51add50a56fcb2   65e5954f46b29e1208590121
# 3  adeeaf4e089a4730bc51add50a56fcb2   65e5954f46b29e1208590121
# 4  adeeaf4e089a4730bc51add50a56fcb2   65e5954f46b29e1208590121
# 5                              None   65e5954f46b29e1208590121
#
#    tags.mlflow.domino.run_number             tags.trial_name  \
# 0                              4  train_function_0be04_00004
# 1                              4  train_function_0be04_00002
# 2                              4  train_function_0be04_00003
# 3                              4  train_function_0be04_00000
# 4                              4  train_function_0be04_00001
# 5                              4                        None
#
#    tags.mlflow.domino.project_name tags.mlflow.domino.project_id
# 0                     mlflow-demos      65e5557490758361e5bc348d
# 1                     mlflow-demos      65e5557490758361e5bc348d
# 2                     mlflow-demos      65e5557490758361e5bc348d
# 3                     mlflow-demos      65e5557490758361e5bc348d
# 4                     mlflow-demos      65e5557490758361e5bc348d
# 5                     mlflow-demos      65e5557490758361e5bc348d
#
# [6 rows x 38 columns]
